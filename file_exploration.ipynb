# %%
import xarray as xr

# %%
drift_file = xarray.open_dataset('./data/drift_maverage.nc')
drift_file
# Out:
# <xarray.Dataset>
# Dimensions:                   (time: 6, bnds: 2, yc: 177, xc: 119)
# Coordinates:
#   * time                      (time) datetime64[ns] 2019-11-30T12:00:00 ... 2...
#     lon                       (yc, xc) float32 ...
#     lat                       (yc, xc) float32 ...
#   * xc                        (xc) float64 -3.75e+03 -3.688e+03 ... 3.625e+03
#   * yc                        (yc) float64 5.75e+03 5.688e+03 ... -5.25e+03
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds                 (time, bnds) datetime64[ns] ...
#     Polar_Stereographic_Grid  int32 ...
#     dt0                       (time, yc, xc) timedelta64[ns] ...
#     lon1                      (time, yc, xc) float32 ...
#     lat1                      (time, yc, xc) float32 ...
#     dt1                       (time, yc, xc) timedelta64[ns] ...
#     dX                        (time, yc, xc) float32 ...
#     dY                        (time, yc, xc) float32 ...
# ...

# %%
drift_file.dX
# Out:
# <xarray.DataArray 'dX' (time: 6, yc: 177, xc: 119)>
# [126378 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2019-11-30T12:00:00 ... 2020-04-30T12:00:00
#     lon      (yc, xc) float32 168.1 167.7 167.2 166.8 ... -11.31 -10.84 -10.38
#     lat      (yc, xc) float32 31.96 32.2 32.44 32.68 ... 36.24 35.98 35.73 35.47
#   * xc       (xc) float64 -3.75e+03 -3.688e+03 ... 3.562e+03 3.625e+03
#   * yc       (yc) float64 5.75e+03 5.688e+03 5.625e+03 ... -5.188e+03 -5.25e+03
# Attributes:
#     standard_name:        sea_ice_x_displacement
#     long_name:            component of the displacement along the x axis of t...
#     units:                km
#     grid_mapping:         Polar_Stereographic_Grid
#     ancillary_variables:  uncert_dX_and_dY status_flag

# %%
drift_file.plot.quiver('xc', 'yc', 'dX', 'dY' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 drift_file.plot.quiver('xc', 'yc', 'dX', 'dY' )
#
# File ~/opt/anaconda3/envs/AWI-env/lib/python3.8/site-packages/xarray/plot/dataset_plot.py:472, in _dsplot.<locals>.plotmethod(_PlotMethods_obj, x, y, u, v, hue, hue_style, col, row, ax, figsize, col_wrap, sharex, sharey, aspect, size, subplot_kws, add_guide, cbar_kwargs, cbar_ax, vmin, vmax, norm, infer_intervals, center, levels, robust, colors, extend, cmap, **kwargs)
#     470 for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#     471     del allargs[arg]
# --> 472 return newplotfunc(**allargs)
#
# ...
